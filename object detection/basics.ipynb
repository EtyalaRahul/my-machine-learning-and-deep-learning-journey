# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in e:\ml\.venv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in e:\ml\.venv\lib\site-packages (from opencv-python) (2.2.6)

# %%
import cv2 
cv2.__version__
# Out:
# '4.12.0'

# %%
# READING IMAGE
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("apple.jpg")



img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)  
plt.axis("off")   
plt.show()

# %%
# resizing image
import cv2
from matplotlib import pyplot as plt

image_path = 'apple.jpg'
image = cv2.imread(image_path)
resized_image = cv2.resize(image, (1900, 800))
resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)
plt.imshow(resized_image_rgb)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
#rotated image  90 degrees

rotated_image=cv2.rotate(image,cv2.ROTATE_90_CLOCKWISE)

rotated_image=cv2.cvtColor(rotated_image,cv2.COLOR_BGR2RGB)

plt.imshow(rotated_image)
plt.axis('off')
plt.title("rotated image")
plt.show()

# %%
##rotated image 

rotated_image=cv2.rotate(image,cv2.ROTATE_90_COUNTERCLOCKWISE)

rotated_image=cv2.cvtColor(rotated_image,cv2.COLOR_BGR2RGB)

plt.imshow(rotated_image)
plt.axis('off')
plt.title("rotated image")
plt.show()

# %%
##rotated image 

rotated_image=cv2.rotate(image,cv2.ROTATE_180)

rotated_image=cv2.cvtColor(rotated_image,cv2.COLOR_BGR2RGB)

plt.imshow(rotated_image)
plt.axis('off')
plt.title("rotated image")
plt.show()
