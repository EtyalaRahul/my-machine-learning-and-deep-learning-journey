# %% [markdown]
# ## Decorators
#
# Decortors are a powerful and flexible feature in python that allows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code.

# %%
## function copy 

def welcome() :
    return "welcome to the python advanced class"

# %%
wel=welcome()
print(wel)
# Out:
# welcome to the python advanced class
