# %% [markdown]
# ## SQL and SQLite
#
# Sql(structured query language) is a standard language for managing and manipulating relational databases. Sqlite is a self-contained, and zero-configuration databases engine that is widely used for embedded database systems.

# %%
import sqlite3

# %%
## connect to an sqlite database 
connection=sqlite3.connect('example.db')
connection
